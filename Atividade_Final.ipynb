# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasFelipeNunes/Exercicios-Inteligencia-Artificial/blob/main/Atividade_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade de Inteligência Artificial

# %% [markdown]
# ## Autoria

# %% [markdown]
# **Alunos:** Lucas Felipe da Silva Nunes e Luiz Gustavo Duarte Chagas
#
# **Professor:** Cristóvão José Dias da Cunha
#
# **Curso:** Análise e Desenvolvimento de Sistemas (6º ADS)
#
# **Faculdade de Tecnologia de Guaratinguetá Professor João Mod**

# %% [markdown]
# ## Escopo

# %% [markdown]
# Neste projeto, é analisada uma [base de dados](https://www.kaggle.com/datasets/bhadramohit/mental-health-dataset), no formato CSV, que contém informações sobre pacientes que foram registrados em um hospital, incluindo dados pessoais, profissionais e a informação de se eles tem uma condição de saúde mental ou não.
#
# Este notebook busca analisar como pode se melhor treinar uma Inteligência Artificial para analisar esse tipo de dados e fazer predições com base neles.

# %% [markdown]
# ## Importação das Bibliotecas

# %% [markdown]
# Para isso, primeiramente, importa-se as bibliotecas que serão utilizadas - incluiundo a do próprio Google Drive, em que se está armazenado o banco de dados.

# %%
# !pip install lazypredict
# !pip install scikit-learn
# Out:
# Requirement already satisfied: lazypredict in /usr/local/lib/python3.10/dist-packages (0.2.13)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.66.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.10/dist-packages (from lazypredict) (4.5.0)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (from lazypredict) (2.1.2)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from lightgbm->lazypredict) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->lazypredict) (2024.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.10/dist-packages (from xgboost->lazypredict) (2.23.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

from lazypredict.Supervised import LazyClassifier, LazyRegressor
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Funções Auxiliares

# %% [markdown]
# Além disso, inclui-se como função auxiliar uma corretora de cores, para facilitar a visualização dos dados na tabela de correlação que será analisada posteriormente.

# %% [markdown]
# ### Função para Colorir a Tabela de Correlação

# %%
def color_corr ( value_str ):
  try:
    value = float(value_str)
    if value >= 0.6 or value <= -0.6:
      color = 'red'
    else:
      color = 'blue'
  except:
          color = 'blue'
  return 'color: %s' % color

# %% [markdown]
# ## Importação de Dados

# %% [markdown]
# Começando o fluxo principal do código, a primeira coisa que se faz é importar os dados da base.

# %%
df=pd.read_csv('/content/drive/My Drive/mental_health_dataset_corrigido.csv', delimiter=';')
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# %%
print(df.columns)
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Occupation', 'Country',
#        'Mental_Health_Condition', 'Severity', 'Consultation_History',
#        'Stress_Level', 'Sleep_Hours', 'Work_Hours', 'Physical_Activity_Hours'],
#       dtype='object')

# %% [markdown]
# Para se visualizar o formato da base de dados, pode se imprimir as suas primeiras linhas.

# %%
df.head(20)
# Out:
#     User_ID  Age             Gender   Occupation    Country  \
# 0         1   36         Non-binary        Sales     Canada
# 1         2   34             Female    Education         UK
# 2         3   65         Non-binary        Sales        USA
# 3         4   34               Male        Other  Australia
# 4         5   22             Female   Healthcare     Canada
# 5         6   64         Non-binary           IT         UK
# 6         7   26             Female  Engineering         UK
# 7         8   57               Male           IT         UK
# 8         9   25               Male    Education        USA
# 9        10   65         Non-binary   Healthcare      India
# 10       11   52             Female        Other      India
# 11       12   23               Male  Engineering     Canada
# 12       13   36             Female      Finance         UK
# 13       14   30         Non-binary        Other      Other
# 14       15   30             Female        Other      India
# 15       16   23             Female      Finance  Australia
# 16       17   18  Prefer not to say    Education        USA
# 17       18   30               Male        Sales  Australia
# 18       19   53  Prefer not to say  Engineering  Australia
# 19       20   42         Non-binary    Education     Canada
#
#    Mental_Health_Condition Severity Consultation_History Stress_Level  \
# 0                       No      NaN                  Yes       Medium
# 1                      Yes      Low                   No          Low
# 2                      Yes     High                   No          Low
# 3                       No      NaN                   No       Medium
# 4                      Yes      Low                   No       Medium
# 5                      Yes     High                   No         High
# 6                       No      NaN                   No       Medium
# 7                      Yes   Medium                  Yes         High
# 8                      Yes      Low                   No       Medium
# 9                       No      NaN                  Yes          Low
# 10                      No      NaN                   No       Medium
# 11                     Yes      Low                   No         High
# 12                     Yes      Low                   No          Low
# 13                      No      NaN                  Yes         High
# 14                     Yes      Low                   No         High
# 15                      No      NaN                   No          Low
# 16                     Yes      Low                   No       Medium
# 17                      No      NaN                  Yes         High
# 18                      No      NaN                   No          Low
# 19                     Yes     High                   No          Low
#
#     Sleep_Hours  Work_Hours  Physical_Activity_Hours
# 0          7.10          46                        5
# 1          7.50          47                        8
# 2          8.40          58                       10
# 3          9.80          30                        2
# 4          4.90          62                        5
# 5          6.30          34                        0
# 6          5.10          58                        6
# 7          4.20          57                        9
# 8          6.70          67                        9
# 9          8.90          57                        6
# 10         8.30          79                       10
# 11         5.70          57                        2
# 12         4.10          77                        5
# 13         9.90          58                        2
# 14         6.90          40                        2
# 15         9.50          39                        9
# 16         8.80          74                        5
# 17         8.00          38                        9
# 18         6.90          50                        4
# 19         8.50          36                        2

# %% [markdown]
# ## Retirando Colunas Inutilzadas

# %% [markdown]
# Como se pode ver, a tabela contém uma coluna que não diz nada sobre o paciente ou sua condição mental: a User_ID. Portanto, pode-se removê-la.

# %%
df.drop(['User_ID'],axis=1,inplace=True)

# %% [markdown]
# Além disso, a coluna **Severity** não será utilizada por este modelo; afinal, não se sabe a serveridade de uma condição mental antes que descubra, primeiro, se ela existe. Removendo esta coluna:

# %%
df.drop(['Severity'],axis=1,inplace=True)

# %% [markdown]
# Após este processo, as colunas do base de dados ficam conforme se segue:

# %%
df.head()
# Out:
#    Age      Gender  Occupation    Country Mental_Health_Condition  \
# 0   36  Non-binary       Sales     Canada                      No
# 1   34      Female   Education         UK                     Yes
# 2   65  Non-binary       Sales        USA                     Yes
# 3   34        Male       Other  Australia                      No
# 4   22      Female  Healthcare     Canada                     Yes
#
#   Consultation_History Stress_Level  Sleep_Hours  Work_Hours  \
# 0                  Yes       Medium         7.10          46
# 1                   No          Low         7.50          47
# 2                   No          Low         8.40          58
# 3                   No       Medium         9.80          30
# 4                   No       Medium         4.90          62
#
#    Physical_Activity_Hours
# 0                        5
# 1                        8
# 2                       10
# 3                        2
# 4                        5

# %% [markdown]
# ## Transformando Colunas Categóricas em Numéricas

# %% [markdown]
# Também é importante se analisar as colunas categóricas: ou seja, aquelas que contém uma enumeração de valores que podem estar registradas. A intenção e transformá-las em numéricas, para facilitar a análise do modelo. Nesta base de dados, essas colunas são:

# %%
df.select_dtypes(include=['object'])
# Out:
#          Gender   Occupation    Country Mental_Health_Condition  \
# 0    Non-binary        Sales     Canada                      No
# 1        Female    Education         UK                     Yes
# 2    Non-binary        Sales        USA                     Yes
# 3          Male        Other  Australia                      No
# 4        Female   Healthcare     Canada                     Yes
# ..          ...          ...        ...                     ...
# 495  Non-binary   Healthcare     Canada                     Yes
# 496      Female        Sales         UK                     Yes
# 497        Male           IT     Canada                     Yes
# 498  Non-binary   Healthcare      India                     Yes
# 499      Female  Engineering     Canada                     Yes
#
#     Consultation_History Stress_Level
# 0                    Yes       Medium
# 1                     No          Low
# 2                     No          Low
# 3                     No       Medium
# 4                     No       Medium
# ..                   ...          ...
# 495                  Yes         High
# 496                  Yes       Medium
# 497                  Yes         High
# 498                  Yes       Medium
# 499                  Yes          Low
#
# [500 rows x 6 columns]

# %% [markdown]
# Para se fazer este processo, primeiro atribui-se as colunas a uma variável **colunas_object**.

# %%
colunas_object = list(df.select_dtypes(include=['object']).columns)
colunas_object
# Out:
# ['Gender',
#  'Occupation',
#  'Country',
#  'Mental_Health_Condition',
#  'Consultation_History',
#  'Stress_Level']

# %% [markdown]
# ### Transformando-as em Colunas Númericas (Técnica Dummie)

# %% [markdown]
# Depois, utiliza-se este objeto para orientar a função **get_dummies** para transformar as colunas categóricas em numéricas pela Técnica Dummie.

# %%
df = pd.get_dummies( df, columns = colunas_object )

# %% [markdown]
# Após estes processos, as colunas da tabela ficam da seguinte forma:

# %%
df.head()
# Out:
#    Age  Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 0   36         7.10          46                        5          False
# 1   34         7.50          47                        8           True
# 2   65         8.40          58                       10          False
# 3   34         9.80          30                        2          False
# 4   22         4.90          62                        5           True
#
#    Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 0        False               True                     False
# 1        False              False                     False
# 2        False               True                     False
# 3         True              False                     False
# 4        False              False                     False
#
#    Occupation_Education  Occupation_Engineering  ...  Country_Other  \
# 0                 False                   False  ...          False
# 1                  True                   False  ...          False
# 2                 False                   False  ...          False
# 3                 False                   False  ...          False
# 4                 False                   False  ...          False
#
#    Country_UK  Country_USA  Mental_Health_Condition_No  \
# 0       False        False                        True
# 1        True        False                       False
# 2       False         True                       False
# 3       False        False                        True
# 4       False        False                       False
#
#    Mental_Health_Condition_Yes  Consultation_History_No  \
# 0                        False                    False
# 1                         True                     True
# 2                         True                     True
# 3                        False                     True
# 4                         True                     True
#
#    Consultation_History_Yes  Stress_Level_High  Stress_Level_Low  \
# 0                      True              False             False
# 1                     False              False              True
# 2                     False              False              True
# 3                     False              False             False
# 4                     False              False             False
#
#    Stress_Level_Medium
# 0                 True
# 1                False
# 2                False
# 3                 True
# 4                 True
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Removendo Dados com Alta Correlação

# %% [markdown]
# Como se pode notar, as colunas que permitem apenas o registro de valores em uma enumeração entre dois possíveis geram colunas númericas completamente inversamente correlacionadas. Desta forma, pode-se retirar uma das colunas númericas geradas neste caso. Analisando a tabela de correlação para ver quais são os casos:

# %%
df.corr().style.applymap(color_corr)
# Out:
# <style type="text/css">
# %% [markdown]
# Pode-se notar que existem duas colunas categóricas que geram tal correlação: **Mental_Health_Condition** e **Consultation_History**, ambas que tem como opções apenas **Yes** e **No**. Portanto, pode-se remover uma dessas duas colunas numéricas geradas por cada campo (aqui escolheu-se remover as da opção **No**).

# %%
df.drop(['Mental_Health_Condition_No', 'Consultation_History_No'], axis=1, inplace=True)

# %% [markdown]
# Além disso, vale-se observar também as colunas com mais de duas opções. Caso as opções sejam compreensivas, de forma que não tenha como existir outra opção além das apresentadas na base de dados, pode-se remover uma das colunas - já que a abscência de valores em todas as outras implicaria, necessariamente, no preenchimento dela.
#
# As colunas **Occupation** e **Country** cumprem este requisito, por causa da opção **Other**. Então, pode-se remover a coluna com esta opção. Além disso, a **Stress_Level** também cumpre: neste contexto, não há outra opção para o nível de estresse além de baixo (**Low**), médio (**Medium**) ou alto (**High**). Portanto, pode-se remover uma de suas colunas também (aqui removeu-se a do **High**).

# %%
df.drop(['Country_Other'], axis=1, inplace=True)
df.drop(['Occupation_Other'], axis=1, inplace=True)
df.drop(['Stress_Level_High'], axis=1, inplace=True)

# %% [markdown]
# Após as remoções, os campos do dataset ficaram como se segue.

# %%
df.head()
# Out:
#    Age  Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 0   36         7.10          46                        5          False
# 1   34         7.50          47                        8           True
# 2   65         8.40          58                       10          False
# 3   34         9.80          30                        2          False
# 4   22         4.90          62                        5           True
#
#    Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 0        False               True                     False
# 1        False              False                     False
# 2        False               True                     False
# 3         True              False                     False
# 4        False              False                     False
#
#    Occupation_Education  Occupation_Engineering  ...  Country_Australia  \
# 0                 False                   False  ...              False
# 1                  True                   False  ...              False
# 2                 False                   False  ...              False
# 3                 False                   False  ...               True
# 4                 False                   False  ...              False
#
#    Country_Canada  Country_Germany  Country_India  Country_UK  Country_USA  \
# 0            True            False          False       False        False
# 1           False            False          False        True        False
# 2           False            False          False       False         True
# 3           False            False          False       False        False
# 4            True            False          False       False        False
#
#    Mental_Health_Condition_Yes  Consultation_History_Yes  Stress_Level_Low  \
# 0                        False                      True             False
# 1                         True                     False              True
# 2                         True                     False              True
# 3                        False                     False             False
# 4                         True                     False             False
#
#    Stress_Level_Medium
# 0                 True
# 1                False
# 2                False
# 3                 True
# 4                 True
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Separando Dados de Treino e Teste

# %% [markdown]
# Após isso, pode-se separar os dados da base em dados de treinamento do modelo (que correspondem a 80% do total), e dados de teste (que correspondem a 20% do total).

# %%
train , test = train_test_split(df, train_size=0.8, random_state=64)

# %% [markdown]
# ## Separando as Variáveis Alvo (Y) das Características (X)

# %% [markdown]
# Feito isso, pode-se separar o campo da variável alvo Y dos campos das características X. Neste caso, como se busca observar a tendência de condições de saúde mental, separa-se o campo **Mental_Health_Condition_Yes** como o Y, dos outros campos X.

# %%
train_x = train.drop(columns=['Mental_Health_Condition_Yes'], axis=1)
train_y = train['Mental_Health_Condition_Yes']

# %%
test_x = test.drop(columns=['Mental_Health_Condition_Yes'], axis=1)
test_y = test['Mental_Health_Condition_Yes']

# %% [markdown]
# Visualizando os resultados destes processos:

# %%
train_x.head()
# Out:
#      Age  Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 462   45         5.30          63                        4          False
# 403   35         5.30          60                        4          False
# 415   36         5.20          64                        6          False
# 127   55         6.50          67                        0          False
# 417   31         5.00          60                        4           True
#
#      Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 462        False               True                     False
# 403        False              False                      True
# 415         True              False                     False
# 127        False               True                     False
# 417        False              False                     False
#
#      Occupation_Education  Occupation_Engineering  ...  Occupation_Sales  \
# 462                 False                   False  ...              True
# 403                 False                   False  ...             False
# 415                 False                   False  ...             False
# 127                 False                    True  ...             False
# 417                 False                    True  ...             False
#
#      Country_Australia  Country_Canada  Country_Germany  Country_India  \
# 462               True           False            False          False
# 403              False           False            False          False
# 415               True           False            False          False
# 127              False            True            False          False
# 417              False            True            False          False
#
#      Country_UK  Country_USA  Consultation_History_Yes  Stress_Level_Low  \
# 462       False        False                      True              True
# 403        True        False                     False             False
# 415       False        False                      True             False
# 127       False        False                      True             False
# 417       False        False                     False             False
#
#      Stress_Level_Medium
# 462                False
# 403                False
# 415                 True
# 127                 True
# 417                False
#
# [5 rows x 23 columns]

# %%
train_y.head()
# Out:
# 462     True
# 403     True
# 415     True
# 127    False
# 417     True
# Name: Mental_Health_Condition_Yes, dtype: bool

# %%
test_x.head()
# Out:
#      Age  Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 240   41         4.60          63                        1          False
# 340   46         5.60          60                        8          False
# 215   31         7.30          60                        6           True
# 57    54         6.00          71                       10          False
# 244   31         7.30          55                        8           True
#
#      Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 240        False               True                     False
# 340         True              False                     False
# 215        False              False                     False
# 57         False               True                     False
# 244        False              False                     False
#
#      Occupation_Education  Occupation_Engineering  ...  Occupation_Sales  \
# 240                 False                   False  ...             False
# 340                 False                   False  ...              True
# 215                 False                    True  ...             False
# 57                   True                   False  ...             False
# 244                 False                   False  ...             False
#
#      Country_Australia  Country_Canada  Country_Germany  Country_India  \
# 240              False           False            False          False
# 340              False           False            False          False
# 215              False           False            False           True
# 57               False           False            False          False
# 244              False            True            False          False
#
#      Country_UK  Country_USA  Consultation_History_Yes  Stress_Level_Low  \
# 240        True        False                      True             False
# 340       False         True                      True              True
# 215       False        False                     False              True
# 57         True        False                      True             False
# 244       False        False                     False             False
#
#      Stress_Level_Medium
# 240                False
# 340                False
# 215                False
# 57                  True
# 244                 True
#
# [5 rows x 23 columns]

# %%
test_y.head()
# Out:
# 240     True
# 340     True
# 215    False
# 57     False
# 244    False
# Name: Mental_Health_Condition_Yes, dtype: bool

# %% [markdown]
# ## Treinando o Modelo

# %% [markdown]
# Nesta etapa, treina-se o modelo com os algorítimos supervisionados de classificação. Foram escolhidos seis algoritmos para o treinamento:
#
# - Regressão Logística
# - Análise Discriminante Linear
# - Árvore de Decisão
# - K Vizinhos Mais Próximos
# - Máquinas de Vetores de Suporte
# - Floresta Aleatória

# %%
LR  = LogisticRegression(solver='lbfgs', max_iter=1000).fit(train_x, train_y)
LDA = LinearDiscriminantAnalysis().fit(train_x, train_y)
DT  = DecisionTreeClassifier().fit(train_x, train_y)
KN  = KNeighborsClassifier().fit(train_x, train_y)
SVM = SVC().fit(train_x,train_y)
RF  = RandomForestClassifier().fit(train_x,train_y)

# %% [markdown]
# ## Métricas da Matriz de Confusão

# %% [markdown]
# Feito o treinamento, pode-se obter as métricas de cada algoritmo com os dados de teste

# %%
metricas = {'Acurácia': [LR.score(test_x,test_y),
                         LDA.score(test_x,test_y),
                         DT.score(test_x,test_y),
                         KN.score(test_x,test_y),
                         SVM.score(test_x,test_y),
                         RF.score(test_x,test_y)],
            'Precisão': [precision_score(test_y, LR.predict(test_x)),
                      precision_score(test_y, LDA.predict(test_x)),
                      precision_score(test_y, DT.predict(test_x)),
                      precision_score(test_y, KN.predict(test_x)),
                      precision_score(test_y, SVM.predict(test_x)),
                      precision_score(test_y, RF.predict(test_x))],
            'Revocação' : [recall_score(test_y, RF.predict(test_x)),
                    recall_score(test_y, LDA.predict(test_x)),
                    recall_score(test_y, DT.predict(test_x)),
                    recall_score(test_y, KN.predict(test_x)),
                    recall_score(test_y, SVM.predict(test_x)),
                    recall_score(test_y, RF.predict(test_x))],
            'F1' : [f1_score(test_y, RF.predict(test_x)),
                    f1_score(test_y, LDA.predict(test_x)),
                    f1_score(test_y, DT.predict(test_x)),
                    f1_score(test_y, KN.predict(test_x)),
                    f1_score(test_y, SVM.predict(test_x)),
                    f1_score(test_y, RF.predict(test_x))]
        }

dados = pd.DataFrame(metricas,
                     columns = ['Acurácia', 'Precisão','Revocação','F1'],
                     index=['LR','LDA','DT','KNN','SVM','RF'])

dados
# Out:
#      Acurácia  Precisão  Revocação   F1
# LR       0.85      0.87       0.92 0.94
# LDA      0.86      0.89       0.92 0.90
# DT       0.85      0.89       0.90 0.90
# KNN      0.74      0.76       0.93 0.84
# SVM      0.72      0.72       1.00 0.84
# RF       0.91      0.96       0.92 0.94

# %%
print(confusion_matrix(test_y, SVM.predict(test_x)))
# Out:
# [[ 0 28]
#  [ 0 72]]

# %% [markdown]
# ## Análise de Resultados e Remodelagem

# %% [markdown]
# Como se pode ver, os modelos ficaram com uma média de 50% em todos os casos.

# %%
def categorize_age(age):
    if age < 18:
        return 'Under 18'
    elif age <= 34:
        return '18-34'
    elif age <= 49:
        return '35-49'
    elif age <= 64:
        return '50-64'
    else:
        return '65+'

df['Age_Range'] = df['Age'].apply(categorize_age)
df.drop(['Age'],axis=1,inplace=True)

df.head()
# Out:
#    Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 0         7.10          46                        5          False
# 1         7.50          47                        8           True
# 2         8.40          58                       10          False
# 3         9.80          30                        2          False
# 4         4.90          62                        5           True
#
#    Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 0        False               True                     False
# 1        False              False                     False
# 2        False               True                     False
# 3         True              False                     False
# 4        False              False                     False
#
#    Occupation_Education  Occupation_Engineering  Occupation_Finance  ...  \
# 0                 False                   False               False  ...
# 1                  True                   False               False  ...
# 2                 False                   False               False  ...
# 3                 False                   False               False  ...
# 4                 False                   False               False  ...
#
#    Country_Canada  Country_Germany  Country_India  Country_UK  Country_USA  \
# 0            True            False          False       False        False
# 1           False            False          False        True        False
# 2           False            False          False       False         True
# 3           False            False          False       False        False
# 4            True            False          False       False        False
#
#    Mental_Health_Condition_Yes  Consultation_History_Yes  Stress_Level_Low  \
# 0                        False                      True             False
# 1                         True                     False              True
# 2                         True                     False              True
# 3                        False                     False             False
# 4                         True                     False             False
#
#    Stress_Level_Medium  Age_Range
# 0                 True      35-49
# 1                False      18-34
# 2                False        65+
# 3                 True      18-34
# 4                 True      18-34
#
# [5 rows x 24 columns]

# %%
def categorize_work_hours(work_hours):
    if work_hours < 30:
        return '30-'
    elif work_hours <= 35:
        return '30-35'
    elif work_hours <= 40:
        return '35-40'
    elif work_hours <= 45:
        return '40-45'
    else:
        return '45+'

df['Work_Hours_Range'] = df['Work_Hours'].apply(categorize_work_hours)
df.drop(['Work_Hours'],axis=1,inplace=True)

df.head()
# Out:
#    Sleep_Hours  Physical_Activity_Hours  Gender_Female  Gender_Male  \
# 0         7.10                        5          False        False
# 1         7.50                        8           True        False
# 2         8.40                       10          False        False
# 3         9.80                        2          False         True
# 4         4.90                        5           True        False
#
#    Gender_Non-binary  Gender_Prefer not to say  Occupation_Education  \
# 0               True                     False                 False
# 1              False                     False                  True
# 2               True                     False                 False
# 3              False                     False                 False
# 4              False                     False                 False
#
#    Occupation_Engineering  Occupation_Finance  Occupation_Healthcare  ...  \
# 0                   False               False                  False  ...
# 1                   False               False                  False  ...
# 2                   False               False                  False  ...
# 3                   False               False                  False  ...
# 4                   False               False                   True  ...
#
#    Country_Germany  Country_India  Country_UK  Country_USA  \
# 0            False          False       False        False
# 1            False          False        True        False
# 2            False          False       False         True
# 3            False          False       False        False
# 4            False          False       False        False
#
#    Mental_Health_Condition_Yes  Consultation_History_Yes  Stress_Level_Low  \
# 0                        False                      True             False
# 1                         True                     False              True
# 2                         True                     False              True
# 3                        False                     False             False
# 4                         True                     False             False
#
#    Stress_Level_Medium  Age_Range  Work_Hours_Range
# 0                 True      35-49               45+
# 1                False      18-34               45+
# 2                False        65+               45+
# 3                 True      18-34             30-35
# 4                 True      18-34               45+
#
# [5 rows x 24 columns]

# %%
def categorize_sleep_hours(sleep_hours):
    if sleep_hours < 6:
        return '6-'
    elif sleep_hours <= 8:
        return '6-8'
    elif sleep_hours <= 10:
        return '8-10'
    else:
        return '10+'

df['Sleep_Hours_Range'] = df['Sleep_Hours'].apply(categorize_sleep_hours)
df.drop(['Sleep_Hours'],axis=1,inplace=True)

df.head()
# Out:
#    Physical_Activity_Hours  Gender_Female  Gender_Male  Gender_Non-binary  \
# 0                        5          False        False               True
# 1                        8           True        False              False
# 2                       10          False        False               True
# 3                        2          False         True              False
# 4                        5           True        False              False
#
#    Gender_Prefer not to say  Occupation_Education  Occupation_Engineering  \
# 0                     False                 False                   False
# 1                     False                  True                   False
# 2                     False                 False                   False
# 3                     False                 False                   False
# 4                     False                 False                   False
#
#    Occupation_Finance  Occupation_Healthcare  Occupation_IT  ...  \
# 0               False                  False          False  ...
# 1               False                  False          False  ...
# 2               False                  False          False  ...
# 3               False                  False          False  ...
# 4               False                   True          False  ...
#
#    Country_India  Country_UK  Country_USA  Mental_Health_Condition_Yes  \
# 0          False       False        False                        False
# 1          False        True        False                         True
# 2          False       False         True                         True
# 3          False       False        False                        False
# 4          False       False        False                         True
#
#    Consultation_History_Yes  Stress_Level_Low  Stress_Level_Medium  Age_Range  \
# 0                      True             False                 True      35-49
# 1                     False              True                False      18-34
# 2                     False              True                False        65+
# 3                     False             False                 True      18-34
# 4                     False             False                 True      18-34
#
#    Work_Hours_Range  Sleep_Hours_Range
# 0               45+                6-8
# 1               45+                6-8
# 2               45+               8-10
# 3             30-35               8-10
# 4               45+                 6-
#
# [5 rows x 24 columns]

# %%
def categorize_physical_activity_hours(physical_activity_hours):
    if physical_activity_hours < 4:
        return '4-'
    elif physical_activity_hours <= 8:
        return '4-8'
    elif physical_activity_hours <= 12:
        return '8-12'
    elif physical_activity_hours <= 16:
        return '12-16'
    else:
        return '20+'

df['Physical_Activity_Hours_Range'] = df['Physical_Activity_Hours'].apply(categorize_physical_activity_hours)
df.drop(['Physical_Activity_Hours'],axis=1,inplace=True)

df.head()
# Out:
#    Gender_Female  Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 0          False        False               True                     False
# 1           True        False              False                     False
# 2          False        False               True                     False
# 3          False         True              False                     False
# 4           True        False              False                     False
#
#    Occupation_Education  Occupation_Engineering  Occupation_Finance  \
# 0                 False                   False               False
# 1                  True                   False               False
# 2                 False                   False               False
# 3                 False                   False               False
# 4                 False                   False               False
#
#    Occupation_Healthcare  Occupation_IT  Occupation_Sales  ...  Country_UK  \
# 0                  False          False              True  ...       False
# 1                  False          False             False  ...        True
# 2                  False          False              True  ...       False
# 3                  False          False             False  ...       False
# 4                   True          False             False  ...       False
#
#    Country_USA  Mental_Health_Condition_Yes  Consultation_History_Yes  \
# 0        False                        False                      True
# 1        False                         True                     False
# 2         True                         True                     False
# 3        False                        False                     False
# 4        False                         True                     False
#
#    Stress_Level_Low  Stress_Level_Medium  Age_Range  Work_Hours_Range  \
# 0             False                 True      35-49               45+
# 1              True                False      18-34               45+
# 2              True                False        65+               45+
# 3             False                 True      18-34             30-35
# 4             False                 True      18-34               45+
#
#    Sleep_Hours_Range  Physical_Activity_Hours_Range
# 0                6-8                            4-8
# 1                6-8                            4-8
# 2               8-10                           8-12
# 3               8-10                             4-
# 4                 6-                            4-8
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Tendo em vista as métricas apresentadas sobre os modelos treinados, algumas das principais conclusões que pode-se obter são:
# - O treinamento por ??? é o melhor, pois...
# - Os campos que mais interferem no resultado final são...
