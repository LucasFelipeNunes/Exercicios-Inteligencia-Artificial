# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasFelipeNunes/Exercicios-Inteligencia-Artificial/blob/main/Atividade_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade de Inteligência Artificial

# %% [markdown]
# ## Autoria

# %% [markdown]
# **Alunos:** Lucas Felipe da Silva Nunes e Luiz Gustavo Duarte Chagas
#
# **Professor:** Cristóvão José Dias da Cunha
#
# **Curso:** Análise e Desenvolvimento de Sistemas (6º ADS)
#
# **Faculdade de Tecnologia de Guaratinguetá Professor João Mod**

# %% [markdown]
# ## Escopo

# %% [markdown]
# Neste projeto, é analisada uma [base de dados](https://www.kaggle.com/datasets/bhadramohit/mental-health-dataset), no formato CSV, que contém informações sobre pacientes que foram registrados em um hospital, incluindo dados pessoais, profissionais e a informação de se eles tem uma condição de saúde mental ou não.
#
# Este notebook busca analisar como pode se melhor treinar uma Inteligência Artificial para analisar esse tipo de dados e fazer predições com base neles.

# %% [markdown]
# ## Importação das Bibliotecas

# %% [markdown]
# Para isso, primeiramente, importa-se as bibliotecas que serão utilizadas - incluiundo a do próprio Google Drive, em que se está armazenado o banco de dados.

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import RocCurveDisplay
from sklearn.metrics import f1_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Funções Auxiliares

# %% [markdown]
# Além disso, inclui-se como função auxiliar uma corretora de cores, para facilitar a visualização dos dados na tabela de correlação que será analisada posteriormente.

# %% [markdown]
# ### Função para Colorir a Tabela de Correlação

# %%
def color_corr ( value_str ):
  try:
    value = float(value_str)
    if value >= 0.6 or value <= -0.6:
      color = 'red'
    else:
      color = 'blue'
  except:
          color = 'blue'
  return 'color: %s' % color

# %% [markdown]
# ## Importação de Dados

# %% [markdown]
# Começando o fluxo principal do código, a primeira coisa que se faz é importar os dados da base.

# %%
df=pd.read_csv('/content/drive/My Drive/mental_health_dataset.csv')

# %% [markdown]
# Para se visualizar o formato da base de dados, pode se imprimir as suas primeiras linhas.

# %%
df.head()
# Out:
#    User_ID  Age      Gender  Occupation    Country Mental_Health_Condition  \
# 0        1   36  Non-binary       Sales     Canada                      No
# 1        2   34      Female   Education         UK                     Yes
# 2        3   65  Non-binary       Sales        USA                     Yes
# 3        4   34        Male       Other  Australia                      No
# 4        5   22      Female  Healthcare     Canada                     Yes
#
#   Severity Consultation_History Stress_Level  Sleep_Hours  Work_Hours  \
# 0   Medium                  Yes       Medium          7.1          46
# 1      NaN                   No          Low          7.5          47
# 2     High                   No          Low          8.4          58
# 3      Low                   No       Medium          9.8          30
# 4      Low                   No       Medium          4.9          62
#
#    Physical_Activity_Hours
# 0                        5
# 1                        8
# 2                       10
# 3                        2
# 4                        5

# %% [markdown]
# ## Retirando Colunas Inutilzadas

# %% [markdown]
# Como se pode ver, a tabela contém uma coluna que não diz nada sobre o paciente ou sua condição mental: a User_ID. Portanto, pode-se removê-la.

# %%
df.drop(['User_ID'],axis=1,inplace=True)

# %% [markdown]
# Além disso, pode-se ver que a coluna **Severity** contém dados registrados como NaN (Not a Number). Para se ter uma melhor visualização disso, pode-se imprimir os valores e suas quantidades presentes em cada registro neste campo.

# %%
value_counts = df['Severity'].value_counts(dropna=False)
print(value_counts)
# Out:
# Severity
# NaN       501
# Low       176
# Medium    164
# High      159
# Name: count, dtype: int64

# %% [markdown]
# Como, neste projeto, busca-se apenas a identificação de se a pessoa tem alguma condição de saúde mental ou não, e como a remoção de todos os registros **NaN** geraria a perda de metade do dataset, opta-se por remover a coluna de severidade.

# %%
df.drop(['Severity'],axis=1,inplace=True)

# %% [markdown]
# Após este processo, as colunas do base de dados ficam conforme se segue:

# %%
df.head()
# Out:
#    Age      Gender  Occupation    Country Mental_Health_Condition  \
# 0   36  Non-binary       Sales     Canada                      No
# 1   34      Female   Education         UK                     Yes
# 2   65  Non-binary       Sales        USA                     Yes
# 3   34        Male       Other  Australia                      No
# 4   22      Female  Healthcare     Canada                     Yes
#
#   Consultation_History Stress_Level  Sleep_Hours  Work_Hours  \
# 0                  Yes       Medium          7.1          46
# 1                   No          Low          7.5          47
# 2                   No          Low          8.4          58
# 3                   No       Medium          9.8          30
# 4                   No       Medium          4.9          62
#
#    Physical_Activity_Hours
# 0                        5
# 1                        8
# 2                       10
# 3                        2
# 4                        5

# %% [markdown]
# ## Transformando Colunas Categóricas em Numéricas

# %% [markdown]
# Também é importante se analisar as colunas categóricas: ou seja, aquelas que contém uma enumeração de valores que podem estar registradas. A intenção e transformá-las em numéricas, para facilitar a análise do modelo. Nesta base de dados, essas colunas são:

# %%
df.select_dtypes(include=['object'])
# Out:
#                 Gender  Occupation    Country Mental_Health_Condition  \
# 0           Non-binary       Sales     Canada                      No
# 1               Female   Education         UK                     Yes
# 2           Non-binary       Sales        USA                     Yes
# 3                 Male       Other  Australia                      No
# 4               Female  Healthcare     Canada                     Yes
# ..                 ...         ...        ...                     ...
# 995         Non-binary       Other    Germany                      No
# 996               Male       Sales     Canada                      No
# 997             Female          IT    Germany                      No
# 998             Female     Finance  Australia                     Yes
# 999  Prefer not to say       Sales    Germany                      No
#
#     Consultation_History Stress_Level
# 0                    Yes       Medium
# 1                     No          Low
# 2                     No          Low
# 3                     No       Medium
# 4                     No       Medium
# ..                   ...          ...
# 995                  Yes          Low
# 996                   No         High
# 997                  Yes       Medium
# 998                   No       Medium
# 999                  Yes          Low
#
# [1000 rows x 6 columns]

# %% [markdown]
# Para se fazer este processo, primeiro atribui-se as colunas a uma variável **colunas_object**.

# %%
colunas_object = list(df.select_dtypes(include=['object']).columns)
colunas_object
# Out:
# ['Gender',
#  'Occupation',
#  'Country',
#  'Mental_Health_Condition',
#  'Consultation_History',
#  'Stress_Level']

# %% [markdown]
# ### Transformando-as em Colunas Númericas (Técnica Dummie)

# %% [markdown]
# Depois, utiliza-se este objeto para orientar a função **get_dummies** para transformar as colunas categóricas em numéricas pela Técnica Dummie.

# %%
df = pd.get_dummies( df, columns = colunas_object )

# %% [markdown]
# Após estes processos, as colunas da tabela ficam da seguinte forma:

# %%
df.head()
# Out:
#    Age  Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 0   36          7.1          46                        5          False
# 1   34          7.5          47                        8           True
# 2   65          8.4          58                       10          False
# 3   34          9.8          30                        2          False
# 4   22          4.9          62                        5           True
#
#    Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 0        False               True                     False
# 1        False              False                     False
# 2        False               True                     False
# 3         True              False                     False
# 4        False              False                     False
#
#    Occupation_Education  Occupation_Engineering  ...  Country_Other  \
# 0                 False                   False  ...          False
# 1                  True                   False  ...          False
# 2                 False                   False  ...          False
# 3                 False                   False  ...          False
# 4                 False                   False  ...          False
#
#    Country_UK  Country_USA  Mental_Health_Condition_No  \
# 0       False        False                        True
# 1        True        False                       False
# 2       False         True                       False
# 3       False        False                        True
# 4       False        False                       False
#
#    Mental_Health_Condition_Yes  Consultation_History_No  \
# 0                        False                    False
# 1                         True                     True
# 2                         True                     True
# 3                        False                     True
# 4                         True                     True
#
#    Consultation_History_Yes  Stress_Level_High  Stress_Level_Low  \
# 0                      True              False             False
# 1                     False              False              True
# 2                     False              False              True
# 3                     False              False             False
# 4                     False              False             False
#
#    Stress_Level_Medium
# 0                 True
# 1                False
# 2                False
# 3                 True
# 4                 True
#
# [5 rows x 29 columns]

# %% [markdown]
# ## Removendo Dados com Alta Correlação

# %% [markdown]
# Como se pode notar, as colunas que permitem apenas o registro de valores em uma enumeração entre dois possíveis geram colunas númericas completamente inversamente correlacionadas. Desta forma, pode-se retirar uma das colunas númericas geradas neste caso. Analisando a tabela de correlação para ver quais são os casos:

# %%
df.corr().style.applymap(color_corr)
# Out:
# <style type="text/css">
# #T_feb93_row0_col0, #T_feb93_row1_col1, #T_feb93_row2_col2, #T_feb93_row3_col3, #T_feb93_row4_col4, #T_feb93_row5_col5, #T_feb93_row6_col6, #T_feb93_row7_col7, #T_feb93_row8_col8, #T_feb93_row9_col9, #T_feb93_row10_col10, #T_feb93_row11_col11, #T_feb93_row12_col12, #T_feb93_row13_col13, #T_feb93_row14_col14, #T_feb93_row15_col15, #T_feb93_row16_col16, #T_feb93_row17_col17, #T_feb93_row18_col18, #T_feb93_row19_col19, #T_feb93_row20_col20, #T_feb93_row21_col21, #T_feb93_row22_col22, #T_feb93_row22_col23, #T_feb93_row23_col22, #T_feb93_row23_col23, #T_feb93_row24_col24, #T_feb93_row24_col25, #T_feb93_row25_col24, #T_feb93_row25_col25, #T_feb93_row26_col26, #T_feb93_row27_col27, #T_feb93_row28_col28 {
#   color: red;
# }
# #T_feb93_row0_col1, #T_feb93_row0_col2, #T_feb93_row0_col3, #T_feb93_row0_col4, #T_feb93_row0_col5, #T_feb93_row0_col6, #T_feb93_row0_col7, #T_feb93_row0_col8, #T_feb93_row0_col9, #T_feb93_row0_col10, #T_feb93_row0_col11, #T_feb93_row0_col12, #T_feb93_row0_col13, #T_feb93_row0_col14, #T_feb93_row0_col15, #T_feb93_row0_col16, #T_feb93_row0_col17, #T_feb93_row0_col18, #T_feb93_row0_col19, #T_feb93_row0_col20, #T_feb93_row0_col21, #T_feb93_row0_col22, #T_feb93_row0_col23, #T_feb93_row0_col24, #T_feb93_row0_col25, #T_feb93_row0_col26, #T_feb93_row0_col27, #T_feb93_row0_col28, #T_feb93_row1_col0, #T_feb93_row1_col2, #T_feb93_row1_col3, #T_feb93_row1_col4, #T_feb93_row1_col5, #T_feb93_row1_col6, #T_feb93_row1_col7, #T_feb93_row1_col8, #T_feb93_row1_col9, #T_feb93_row1_col10, #T_feb93_row1_col11, #T_feb93_row1_col12, #T_feb93_row1_col13, #T_feb93_row1_col14, #T_feb93_row1_col15, #T_feb93_row1_col16, #T_feb93_row1_col17, #T_feb93_row1_col18, #T_feb93_row1_col19, #T_feb93_row1_col20, #T_feb93_row1_col21, #T_feb93_row1_col22, #T_feb93_row1_col23, #T_feb93_row1_col24, #T_feb93_row1_col25, #T_feb93_row1_col26, #T_feb93_row1_col27, #T_feb93_row1_col28, #T_feb93_row2_col0, #T_feb93_row2_col1, #T_feb93_row2_col3, #T_feb93_row2_col4, #T_feb93_row2_col5, #T_feb93_row2_col6, #T_feb93_row2_col7, #T_feb93_row2_col8, #T_feb93_row2_col9, #T_feb93_row2_col10, #T_feb93_row2_col11, #T_feb93_row2_col12, #T_feb93_row2_col13, #T_feb93_row2_col14, #T_feb93_row2_col15, #T_feb93_row2_col16, #T_feb93_row2_col17, #T_feb93_row2_col18, #T_feb93_row2_col19, #T_feb93_row2_col20, #T_feb93_row2_col21, #T_feb93_row2_col22, #T_feb93_row2_col23, #T_feb93_row2_col24, #T_feb93_row2_col25, #T_feb93_row2_col26, #T_feb93_row2_col27, #T_feb93_row2_col28, #T_feb93_row3_col0, #T_feb93_row3_col1, #T_feb93_row3_col2, #T_feb93_row3_col4, #T_feb93_row3_col5, #T_feb93_row3_col6, #T_feb93_row3_col7, #T_feb93_row3_col8, #T_feb93_row3_col9, #T_feb93_row3_col10, #T_feb93_row3_col11, #T_feb93_row3_col12, #T_feb93_row3_col13, #T_feb93_row3_col14, #T_feb93_row3_col15, #T_feb93_row3_col16, #T_feb93_row3_col17, #T_feb93_row3_col18, #T_feb93_row3_col19, #T_feb93_row3_col20, #T_feb93_row3_col21, #T_feb93_row3_col22, #T_feb93_row3_col23, #T_feb93_row3_col24, #T_feb93_row3_col25, #T_feb93_row3_col26, #T_feb93_row3_col27, #T_feb93_row3_col28, #T_feb93_row4_col0, #T_feb93_row4_col1, #T_feb93_row4_col2, #T_feb93_row4_col3, #T_feb93_row4_col5, #T_feb93_row4_col6, #T_feb93_row4_col7, #T_feb93_row4_col8, #T_feb93_row4_col9, #T_feb93_row4_col10, #T_feb93_row4_col11, #T_feb93_row4_col12, #T_feb93_row4_col13, #T_feb93_row4_col14, #T_feb93_row4_col15, #T_feb93_row4_col16, #T_feb93_row4_col17, #T_feb93_row4_col18, #T_feb93_row4_col19, #T_feb93_row4_col20, #T_feb93_row4_col21, #T_feb93_row4_col22, #T_feb93_row4_col23, #T_feb93_row4_col24, #T_feb93_row4_col25, #T_feb93_row4_col26, #T_feb93_row4_col27, #T_feb93_row4_col28, #T_feb93_row5_col0, #T_feb93_row5_col1, #T_feb93_row5_col2, #T_feb93_row5_col3, #T_feb93_row5_col4, #T_feb93_row5_col6, #T_feb93_row5_col7, #T_feb93_row5_col8, #T_feb93_row5_col9, #T_feb93_row5_col10, #T_feb93_row5_col11, #T_feb93_row5_col12, #T_feb93_row5_col13, #T_feb93_row5_col14, #T_feb93_row5_col15, #T_feb93_row5_col16, #T_feb93_row5_col17, #T_feb93_row5_col18, #T_feb93_row5_col19, #T_feb93_row5_col20, #T_feb93_row5_col21, #T_feb93_row5_col22, #T_feb93_row5_col23, #T_feb93_row5_col24, #T_feb93_row5_col25, #T_feb93_row5_col26, #T_feb93_row5_col27, #T_feb93_row5_col28, #T_feb93_row6_col0, #T_feb93_row6_col1, #T_feb93_row6_col2, #T_feb93_row6_col3, #T_feb93_row6_col4, #T_feb93_row6_col5, #T_feb93_row6_col7, #T_feb93_row6_col8, #T_feb93_row6_col9, #T_feb93_row6_col10, #T_feb93_row6_col11, #T_feb93_row6_col12, #T_feb93_row6_col13, #T_feb93_row6_col14, #T_feb93_row6_col15, #T_feb93_row6_col16, #T_feb93_row6_col17, #T_feb93_row6_col18, #T_feb93_row6_col19, #T_feb93_row6_col20, #T_feb93_row6_col21, #T_feb93_row6_col22, #T_feb93_row6_col23, #T_feb93_row6_col24, #T_feb93_row6_col25, #T_feb93_r ...

# %% [markdown]
# Pode-se notar que existem duas colunas categóricas que geram tal correlação: **Mental_Health_Condition** e **Consultation_History**, ambas que tem como opções apenas **Yes** e **No**. Portanto, pode-se remover uma dessas duas colunas numéricas geradas por cada campo (aqui escolheu-se remover as da opção **No**).

# %%
df.drop(['Mental_Health_Condition_No', 'Consultation_History_No'], axis=1, inplace=True)

# %% [markdown]
# Além disso, vale-se observar também as colunas com mais de duas opções. Caso as opções sejam compreensivas, de forma que não tenha como existir outra opção além das apresentadas na base de dados, pode-se remover uma das colunas - já que a abscência de valores em todas as outras implicaria, necessariamente, no preenchimento dela.
#
# Não se pode dizer isso sobre a coluna **Gender** e **Occupation**, já que existem outras possibilidades de valores além das mencionadas. Entretanto, a **Occupation** e a **Country** cumprem este requisito, por causa da opção **Other**. Então, pode-se remover a coluna com esta opção. Além disso, a **Stress_Level** também cumpre: neste contexto, não há outra opção para o nível de estresse além de baixo (**Low**), médio (**Medium**) ou alto (**High**). Portanto, pode-se remover uma de suas colunas também (aqui removeu-se a do **High**).

# %%
df.drop(['Country_Other'], axis=1, inplace=True)
df.drop(['Occupation_Other'], axis=1, inplace=True)
df.drop(['Stress_Level_High'], axis=1, inplace=True)

# %% [markdown]
# Após as remoções, os campos do dataset ficaram como se segue.

# %%
df.head()
# Out:
#    Age  Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 0   36          7.1          46                        5          False
# 1   34          7.5          47                        8           True
# 2   65          8.4          58                       10          False
# 3   34          9.8          30                        2          False
# 4   22          4.9          62                        5           True
#
#    Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 0        False               True                     False
# 1        False              False                     False
# 2        False               True                     False
# 3         True              False                     False
# 4        False              False                     False
#
#    Occupation_Education  Occupation_Engineering  ...  Country_Australia  \
# 0                 False                   False  ...              False
# 1                  True                   False  ...              False
# 2                 False                   False  ...              False
# 3                 False                   False  ...               True
# 4                 False                   False  ...              False
#
#    Country_Canada  Country_Germany  Country_India  Country_UK  Country_USA  \
# 0            True            False          False       False        False
# 1           False            False          False        True        False
# 2           False            False          False       False         True
# 3           False            False          False       False        False
# 4            True            False          False       False        False
#
#    Mental_Health_Condition_Yes  Consultation_History_Yes  Stress_Level_Low  \
# 0                        False                      True             False
# 1                         True                     False              True
# 2                         True                     False              True
# 3                        False                     False             False
# 4                         True                     False             False
#
#    Stress_Level_Medium
# 0                 True
# 1                False
# 2                False
# 3                 True
# 4                 True
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Separando Dados de Treino e Teste

# %% [markdown]
# Após isso, pode-se separar os dados da base em dados de treinamento do modelo (que correspondem a 80% do total), e dados de teste (que correspondem a 20% do total).

# %%
train , test = train_test_split(df, train_size=0.8, random_state=64)

# %% [markdown]
# ## Separando as Variáveis Alvo (Y) das Características (X)

# %% [markdown]
# Feito isso, pode-se separar o campo da variável alvo Y dos campos das características X. Neste caso, como se busca observar a tendência de condições de saúde mental, separa-se o campo **Mental_Health_Condition_Yes** como o Y, dos outros campos X.

# %%
train_x = train.drop(columns=['Mental_Health_Condition_Yes'], axis=1)
train_y = train['Mental_Health_Condition_Yes']

# %%
test_x = test.drop(columns=['Mental_Health_Condition_Yes'], axis=1)
test_y = test['Mental_Health_Condition_Yes']

# %% [markdown]
# Visualizando os resultados destes processos:

# %%
train_x.head()
# Out:
#      Age  Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 471   65          5.8          42                        1           True
# 988   26          8.4          44                        3           True
# 320   18          5.0          67                        1          False
# 295   50          8.0          31                        3          False
# 310   59          7.7          47                        5          False
#
#      Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 471        False              False                     False
# 988        False              False                     False
# 320         True              False                     False
# 295         True              False                     False
# 310        False              False                      True
#
#      Occupation_Education  Occupation_Engineering  ...  Occupation_Sales  \
# 471                 False                   False  ...             False
# 988                 False                    True  ...             False
# 320                 False                   False  ...              True
# 295                 False                   False  ...             False
# 310                 False                   False  ...             False
#
#      Country_Australia  Country_Canada  Country_Germany  Country_India  \
# 471              False           False            False          False
# 988              False            True            False          False
# 320              False           False            False          False
# 295              False           False            False           True
# 310              False           False            False          False
#
#      Country_UK  Country_USA  Consultation_History_Yes  Stress_Level_Low  \
# 471       False        False                      True              True
# 988       False        False                      True             False
# 320        True        False                     False             False
# 295       False        False                      True              True
# 310        True        False                      True             False
#
#      Stress_Level_Medium
# 471                False
# 988                False
# 320                 True
# 295                False
# 310                False
#
# [5 rows x 23 columns]

# %%
train_y.head()
# Out:
# 799     True
# 471     True
# 242    False
# 704     True
# 839     True
# Name: Mental_Health_Condition_Yes, dtype: bool

# %%
test_x.head()
# Out:
#      Age  Sleep_Hours  Work_Hours  Physical_Activity_Hours  Gender_Female  \
# 632   55          8.9          67                        6          False
# 687   23          7.5          72                        3          False
# 833   60          7.5          77                        0           True
# 182   27          7.9          32                        3          False
# 831   63          5.8          66                        4          False
#
#      Gender_Male  Gender_Non-binary  Gender_Prefer not to say  \
# 632         True              False                     False
# 687        False              False                      True
# 833        False              False                     False
# 182         True              False                     False
# 831         True              False                     False
#
#      Occupation_Education  Occupation_Engineering  ...  Occupation_Sales  \
# 632                 False                   False  ...             False
# 687                 False                   False  ...              True
# 833                 False                   False  ...             False
# 182                 False                   False  ...             False
# 831                 False                   False  ...             False
#
#      Country_Australia  Country_Canada  Country_Germany  Country_India  \
# 632              False            True            False          False
# 687              False           False            False          False
# 833              False           False            False          False
# 182              False           False            False          False
# 831              False           False            False          False
#
#      Country_UK  Country_USA  Consultation_History_Yes  Stress_Level_Low  \
# 632       False        False                     False             False
# 687       False         True                      True             False
# 833       False        False                      True              True
# 182       False         True                      True              True
# 831        True        False                      True              True
#
#      Stress_Level_Medium
# 632                 True
# 687                 True
# 833                False
# 182                False
# 831                False
#
# [5 rows x 23 columns]

# %%
test_y.head()
# Out:
# 632    False
# 687    False
# 833    False
# 182    False
# 831     True
# Name: Mental_Health_Condition_Yes, dtype: bool

# %% [markdown]
# ## Treinando o Modelo

# %% [markdown]
# Nesta etapa, treina-se o modelo com os algorítimos supervisionados de classificação. Foram escolhidos seis algoritmos para o treinamento:
#
# - Regressão Logística
# - Análise Discriminante Linear
# - Árvore de Decisão
# - K Vizinhos Mais Próximos
# - Máquinas de Vetores de Suporte
# - Floresta Aleatória

# %%
LR  = LogisticRegression(solver='lbfgs', max_iter=1000).fit(train_x, train_y)
LDA = LinearDiscriminantAnalysis().fit(train_x, train_y)
DT  = DecisionTreeClassifier().fit(train_x, train_y)
KN  = KNeighborsClassifier().fit(train_x, train_y)
SVM = SVC().fit(train_x,train_y)
RF  = RandomForestClassifier().fit(train_x,train_y)

# %% [markdown]
# ## Métricas da Matriz de Confusão

# %% [markdown]
# Feito o treinamento, pode-se obter as métricas de cada algoritmo com os dados de teste

# %%
metricas = {'Acurácia': [LR.score(test_x,test_y),
                         LDA.score(test_x,test_y),
                         DT.score(test_x,test_y),
                         KN.score(test_x,test_y),
                         SVM.score(test_x,test_y),
                         RF.score(test_x,test_y)],
            'Precisão': [precision_score(test_y, LR.predict(test_x)),
                      precision_score(test_y, LDA.predict(test_x)),
                      precision_score(test_y, DT.predict(test_x)),
                      precision_score(test_y, KN.predict(test_x)),
                      precision_score(test_y, SVM.predict(test_x)),
                      precision_score(test_y, RF.predict(test_x))],
            'Revocação' : [recall_score(test_y, RF.predict(test_x)),
                    recall_score(test_y, LDA.predict(test_x)),
                    recall_score(test_y, DT.predict(test_x)),
                    recall_score(test_y, KN.predict(test_x)),
                    recall_score(test_y, SVM.predict(test_x)),
                    recall_score(test_y, RF.predict(test_x))],
            'F1' : [f1_score(test_y, RF.predict(test_x)),
                    f1_score(test_y, LDA.predict(test_x)),
                    f1_score(test_y, DT.predict(test_x)),
                    f1_score(test_y, KN.predict(test_x)),
                    f1_score(test_y, SVM.predict(test_x)),
                    f1_score(test_y, RF.predict(test_x))]
        }

dados = pd.DataFrame(metricas,
                     columns = ['Acurácia', 'Precisão','Revocação','F1'],
                     index=['LR','LDA','DT','KNN','SVM','RF'])

dados
# Out:
#      Acurácia  Precisão  Revocação        F1
# LR      0.510  0.520000   0.495146  0.470046
# LDA     0.510  0.520000   0.631068  0.570175
# DT      0.465  0.479167   0.446602  0.462312
# KNN     0.425  0.442308   0.446602  0.444444
# SVM     0.510  0.513228   0.941748  0.664384
# RF      0.425  0.447368   0.495146  0.470046

# %% [markdown]
# ## Análise de Resultados e Remodelagem

# %% [markdown]
# Como se pode ver, os modelos ficaram com uma média de 50% em todos os casos. Isso indica que existem muitos campos que não tem qualquer relação com a presença de condição de saúde mental nos entrevistados.
#
# Um campo que pode estar nesta lista é o de ocupação. Embora sejam serviços de natureza diferentes, em termos físicos, as exigências de serviços de venda, educação, engenharia, entre outros mencionados são semelhantes ao corpo humano em natureza.
#
# Analisando e removendo, portanto, os campos relacionados a eles:

# %%
print(train_x.columns)
# Out:
# Index(['Age', 'Sleep_Hours', 'Work_Hours', 'Physical_Activity_Hours',
#        'Gender_Female', 'Gender_Male', 'Gender_Non-binary',
#        'Gender_Prefer not to say', 'Occupation_Education',
#        'Occupation_Engineering', 'Occupation_Finance', 'Occupation_Healthcare',
#        'Occupation_IT', 'Occupation_Sales', 'Country_Australia',
#        'Country_Canada', 'Country_Germany', 'Country_India', 'Country_UK',
#        'Country_USA', 'Consultation_History_Yes', 'Stress_Level_Low',
#        'Stress_Level_Medium'],
#       dtype='object')

# %%
train_x = train_x.drop(columns=['Occupation_Education', 'Occupation_Engineering', 'Occupation_Finance', 'Occupation_Healthcare', 'Occupation_IT', 'Occupation_Sales'], axis=1)
test_x = test_x.drop(columns=['Occupation_Education', 'Occupation_Engineering', 'Occupation_Finance', 'Occupation_Healthcare', 'Occupation_IT', 'Occupation_Sales'], axis=1)
print(train_x.columns)
# Out:
# Index(['Age', 'Sleep_Hours', 'Work_Hours', 'Physical_Activity_Hours',
#        'Gender_Female', 'Gender_Male', 'Gender_Non-binary',
#        'Gender_Prefer not to say', 'Country_Australia', 'Country_Canada',
#        'Country_Germany', 'Country_India', 'Country_UK', 'Country_USA',
#        'Consultation_History_Yes', 'Stress_Level_Low', 'Stress_Level_Medium'],
#       dtype='object')

# %% [markdown]
# Análogamente, os países também não parecem ter uma forte correlação por si próprios com a existência de uma condição de saúde mental ou não. Todos os listados são desenvolvidos ou emergentes, grandes e com bastante população. Removendo também estas colunas:

# %%
train_x = train_x.drop(columns=['Country_Australia', 'Country_Canada',
       'Country_Germany', 'Country_India', 'Country_UK', 'Country_USA'], axis=1)
test_x = test_x.drop(columns=['Country_Australia', 'Country_Canada',
       'Country_Germany', 'Country_India', 'Country_UK', 'Country_USA'], axis=1)
print(train_x.columns)
# Out:
# Index(['Age', 'Sleep_Hours', 'Work_Hours', 'Physical_Activity_Hours',
#        'Gender_Female', 'Gender_Male', 'Gender_Non-binary',
#        'Gender_Prefer not to say', 'Consultation_History_Yes',
#        'Stress_Level_Low', 'Stress_Level_Medium'],
#       dtype='object')

# %%
print(sum(train_y))
# Out:
# 409

# %%
LR  = LogisticRegression(solver='lbfgs', max_iter=100).fit(train_x, train_y)
LDA = LinearDiscriminantAnalysis().fit(train_x, train_y)
DT  = DecisionTreeClassifier().fit(train_x, train_y)
KN  = KNeighborsClassifier().fit(train_x, train_y)
SVM = SVC().fit(train_x,train_y)
RF  = RandomForestClassifier().fit(train_x,train_y)

metricas = {'Acurácia': [LR.score(test_x,test_y),
                         LDA.score(test_x,test_y),
                         DT.score(test_x,test_y),
                         KN.score(test_x,test_y),
                         SVM.score(test_x,test_y),
                         RF.score(test_x,test_y)],
            'Precisão': [precision_score(test_y, LR.predict(test_x)),
                      precision_score(test_y, LDA.predict(test_x)),
                      precision_score(test_y, DT.predict(test_x)),
                      precision_score(test_y, KN.predict(test_x)),
                      precision_score(test_y, SVM.predict(test_x)),
                      precision_score(test_y, RF.predict(test_x))],
            'Revocação' : [recall_score(test_y, RF.predict(test_x)),
                    recall_score(test_y, LDA.predict(test_x)),
                    recall_score(test_y, DT.predict(test_x)),
                    recall_score(test_y, KN.predict(test_x)),
                    recall_score(test_y, SVM.predict(test_x)),
                    recall_score(test_y, RF.predict(test_x))],
            'F1' : [f1_score(test_y, RF.predict(test_x)),
                    f1_score(test_y, LDA.predict(test_x)),
                    f1_score(test_y, DT.predict(test_x)),
                    f1_score(test_y, KN.predict(test_x)),
                    f1_score(test_y, SVM.predict(test_x)),
                    f1_score(test_y, RF.predict(test_x))]
        }

dados = pd.DataFrame(metricas,
                     columns = ['Acurácia', 'Precisão','Revocação','F1'],
                     index=['LR','LDA','DT','KNN','SVM','RF'])

dados
# Out:
#      Acurácia  Precisão  Revocação        F1
# LR      0.535  0.553719   0.537736  0.515837
# LDA     0.540  0.558333   0.632075  0.592920
# DT      0.460  0.490000   0.462264  0.475728
# KNN     0.485  0.514563   0.500000  0.507177
# SVM     0.520  0.530488   0.820755  0.644444
# RF      0.465  0.495652   0.537736  0.515837

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Tendo em vista as métricas apresentadas sobre os modelos treinados, algumas das principais conclusões que pode-se obter são:
# - O treinamento por ??? é o melhor, pois...
# - Os campos que mais interferem no resultado final são...
